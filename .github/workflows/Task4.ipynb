# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
kartik = pd.read_csv('iris.csv')

# %%
kartik
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
kartik2 = pd.get_dummies(kartik, columns=['variety'] , prefix='variety')

# %%
kartik2
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety_Setosa  \
# 0             5.1          3.5           1.4          0.2            True
# 1             4.9          3.0           1.4          0.2            True
# 2             4.7          3.2           1.3          0.2            True
# 3             4.6          3.1           1.5          0.2            True
# 4             5.0          3.6           1.4          0.2            True
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3           False
# 146           6.3          2.5           5.0          1.9           False
# 147           6.5          3.0           5.2          2.0           False
# 148           6.2          3.4           5.4          2.3           False
# 149           5.9          3.0           5.1          1.8           False
#
#      variety_Versicolor  variety_Virginica
# ...

# %%
kartik3 = kartik.copy()

# %%
species_mapping = {
    'Setosa': 0,
    'Versicolor': 1,
    'Virginica': 2
}

kartik3['variety'] = kartik3['variety'].map(species_mapping)

# %%
kartik3
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]
